# %%
import pandas as pd
# %matplotlib inline
raw_train = pd.read_csv("./input/train_sample_utf8.csv",encoding="utf8")
raw_test = pd.read_csv("./input/test_sample_utf8.csv",encoding="utf8")

# %%
raw_train.head(5)
# Out:
#    分类                                                 文章    字数
# 0  科技  “一路听天下”开拓“无聊经济” 在纳斯达克风光上市的分众传媒，得到国际五大风险投资商青睐的炎...  1954
# 1  旅游  中国赴美旅游首发团６月１７日启程　报价两万左右 六月初的一天，来自深圳的中国旅游团游客纷纷拿...  1177
# 2  新闻  科学家教育家蒙特梭利：给孩子爱与自由（图） 蒙特梭利和“儿童之家”的孩子们在一起我们的孩子想...  4571
# 3  教育  ７名大学生作出“震后恢复建议”　获国务院肯定 大学生灾后重建报告获国务院肯定作出４万字建议案...  2288
# 4  教育  最牛高考生：重庆学生称“押中”今年作文题 最牛鼓劲：数学考试前百余考生吼“雄起”“雄起！雄起...  1838

# %%
raw_test.head(5)
# Out:
#     分类                                                 文章
# 0   娱乐  影片《奥林匹亚》 影片《奥林匹亚》影片《奥林匹亚》剧情简介本片如英雄史诗般的奥运纪录片是德国...
# 1   女人  盘点男人出轨都会经历的五个过程 大凡男人都有背叛老婆的野心，或精神的背叛，或身体的背叛，又或...
# 2   文化  欧阳奋强点评新宝玉：他应该能够超越我（图） 来源：中国网四川新闻网－成都商报讯本报讯　（记者...
# 3   体育  法国意大利双雄渐现堕落　欧洲杯让世界杯见鬼去 来源：搜狐体育失望的亨利焦点人物新“三剑客　”...
# 4  房地产  业内论坛 版主：　毕普　ｔａｌｋａｔｉｖｅ　也是另类　华沉思　周海山　成业　醋咪　ｚｈａｍｕ...

# %%
raw_train.shape
# Out:
# (5521, 3)

# %%
raw_test.shape
# Out:
# (3111, 2)

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import _rebuild
_rebuild()
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
raw_train["分类"].value_counts().sort_index().plot(kind="barh",title='训练集新闻主题分布')
plt.subplot(1, 2, 2)
raw_test["分类"].value_counts().sort_index().plot(kind="barh",title='测试集新闻主题分布')
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %%
import jieba
def news_cut(text):
    return " ".join(list(jieba.cut(text)))
#简单测试下分词效果
test_content = "六月初的一天，来自深圳的中国旅游团游客纷纷拿起相机拍摄新奇刺激的好莱坞环球影城主题公园场景。"
print(news_cut(test_content))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/8_/9d4r525j0vd1fjytqf9z099h0000gn/T/jieba.cache
# Loading model cost 0.811 seconds.
# Prefix dict has been built successfully.
# 六月 初 的 一天 ， 来自 深圳 的 中国 旅游团 游客 纷纷 拿 起 相机 拍摄 新奇 刺激 的 好莱坞 环球 影城 主题公园 场景 。

# %%
raw_train["分词文章"] = raw_train["文章"].map(news_cut)
raw_test["分词文章"] = raw_test["文章"].map(news_cut)

# %%
raw_test.head(5)
# Out:
#     分类                                                 文章  \
# 0   娱乐  影片《奥林匹亚》 影片《奥林匹亚》影片《奥林匹亚》剧情简介本片如英雄史诗般的奥运纪录片是德国...
# 1   女人  盘点男人出轨都会经历的五个过程 大凡男人都有背叛老婆的野心，或精神的背叛，或身体的背叛，又或...
# 2   文化  欧阳奋强点评新宝玉：他应该能够超越我（图） 来源：中国网四川新闻网－成都商报讯本报讯　（记者...
# 3   体育  法国意大利双雄渐现堕落　欧洲杯让世界杯见鬼去 来源：搜狐体育失望的亨利焦点人物新“三剑客　”...
# 4  房地产  业内论坛 版主：　毕普　ｔａｌｋａｔｉｖｅ　也是另类　华沉思　周海山　成业　醋咪　ｚｈａｍｕ...
#
#                                                 分词文章
# 0  影片 《 奥林匹亚 》   影片 《 奥林匹亚 》 影片 《 奥林匹亚 》 剧情简介 本片 ...
# 1  盘点 男人 出轨 都 会 经历 的 五个 过程   大凡 男人 都 有 背叛 老婆 的 野心...
# 2  欧阳奋强 点评 新 宝玉 ： 他 应该 能够 超越 我 （ 图 ）   来源 ： 中国 网 ...
# 3  法国 意大利 双雄 渐现 堕落 　 欧洲杯 让 世界杯 见鬼 去   来源 ： 搜狐 体育 ...
# 4  业内 论坛   版主 ： 　 毕普 　 ｔ ａ ｌ ｋ ａ ｔ ｉ ｖ ｅ 　 也 是 另类...

# %%
#加载停用词
# stop_words = []
# file = open("./input/stopwords.txt") 
# for line in file:
#     stop_words.append(line.strip())
# file.close()

stop_words = open("./input/stopwords.txt").read().replace('\n', ' ').split()
print(stop_words)
# Out:
# ['aboard', 'about', 'about', 'about', 'above', 'above', 'according', 'according', 'to', 'across', 'across', 'afore', 'after', 'after', 'after', 'afterwards', 'again', 'against', 'against', 'against', 'agin', 'all', 'all', 'almost', 'almost', 'alone', 'along', 'along', 'alongside', 'already', 'also', 'also', 'although', 'although', 'always', 'am', 'am', 'amid', 'amidst', 'among', 'among', 'among', 'amongst', 'amongst', 'amoungst', 'amount', 'an', 'an', 'an', 'and', 'and', 'anent', 'another', 'another', 'any', 'any', 'anyhow', 'anyone', 'anything', 'anything', 'anyway', 'anywhere', 'approximately', 'are', 'are', 'around', 'around', 'as', 'as', 'as', 'asked', 'aslant', 'astride', 'at', 'at', 'at', 'athwart', 'back', 'back', 'bar', 'be', 'became', 'because', 'because', 'because', 'of', 'become', 'becomes', 'becoming', 'been', 'before', 'before', 'before', 'beforehand', 'behind', 'behind', 'being', 'below', 'below', 'beneath', 'beside', 'beside', 'besides', 'besides', 'besides', 'between', 'between', 'between', 'betwixt', 'beyond', 'beyond', 'bill', 'both', 'both', 'bottom', 'but', 'but', 'but', 'by', 'by', 'by', 'call', 'call', 'called', 'can', 'can', 'cannot', 'cant', 'circa', 'co', 'computer', 'con', 'could', 'could', 'couldnt', 'cry', 'currently', 'dare', 'de', 'describe', 'despite', 'despite', 'detail', 'did', 'did', 'do', 'do', 'do', 'does', 'done', 'down', 'down', 'dr', 'due', 'due', 'to', 'during', 'during', 'during', 'e.g.,', 'each', 'each', 'earlier', 'eg', 'eight', 'eight', 'either', 'eleven', 'else', 'elsewhere', 'empty', 'enough', 'ere', 'etc', 'even', 'even', 'eventually', 'ever', 'every', 'every', 'everyone', 'everything', 'everything', 'everywhere', 'except', 'except', 'few', 'fifteen', 'fify', 'fill', 'find', 'fire', 'first', 'five', 'five', 'for', 'for', 'for', 'former', 'formerly', 'forty', 'found', 'four', 'four', 'from', 'from', 'from', 'front', 'full', 'further', 'get', 'give', 'go', 'had', 'has', 'hasnt', 'have', 'he', 'he', 'he', 'hence', 'her', 'her', 'her', 'here', 'here', 'hereafter', 'hereby', 'herein', 'hereupon', 'hers', 'hers', 'herself', 'herself', 'him', 'him', 'himself', 'himself', 'his', 'his', 'his', 'how', 'how', 'however', 'however', 'hundred', 'i', 'i', 'ie', 'if', 'if', 'in', 'in', 'in', 'inc', 'indeed', 'indeed', 'inside', 'instead', 'interest', 'into', 'into', 'is', 'is', 'it', 'it', 'it', 'its', 'its', 'its', 'itself', 'itself', 'just', 'keep', 'last', 'last', 'latter', 'latterly', 'least', 'less', 'less', 'like', 'like', 'ltd', 'made', 'major', 'many', 'many', 'may', 'may', 'may', 'maybe', 'me', 'me', 'meanwhile', 'meanwhile', 'mid', 'midst', 'might', 'might', 'mill', 'mine', 'mine', 'minus', 'more', 'more', 'moreover', 'moreover', 'most', 'most', 'mostly', 'move', 'mr', 'mrs', 'ms', 'much', 'much', 'must', 'must', 'my', 'my', 'my', 'myself', 'myself', 'name', 'namely', 'near', 'need', 'neither', 'neither', 'net', 'never', 'never', 'nevertheless', 'nevertheless', 'next', 'next', 'nigh', 'nigher', 'nighest', 'nine', 'nine', 'no', 'no', 'nobody', 'none', 'none', 'noone', 'nor', 'not', 'not', 'nothing', 'nothing', 'notwithstanding', 'now', 'now', 'nowhere', 'of', 'of', 'of', 'off', 'off', 'often', 'on', 'on', 'on', 'on', 'to', 'once', 'once', 'one', 'one', 'only', 'only', 'onto', 'onto', 'or', 'or', 'other', 'other', 'others', 'otherwise', 'ought', 'our', 'our', 'our', 'ours', 'ours', 'ourselves', 'ourselves', 'out', 'out', 'out', 'of', 'outside', 'over', 'over', 'over', 'own', 'part', 'partly', 'past', 'pending', 'per', 'per', 'perhaps', 'perhaps', 'please', 'plus', 'prior', 'put', 'qua', 'rather', 're', 're', 'regarding', 'round', 'same', 'sans', 'save', 'see', 'seem', 'seemed', 'seeming', 'seems', 'separately', 'serious', 'seven', 'several', 'several', 'shall', 'she', 'she', 'she', 'should', 'should', 'should', 'show', 'side', 'similarly', 'since', 'since', 'since', 'sincere', 'six', 'six', 'sixty', 'so', 'so', 'some', 'some', 'somehow', 'somehow', 'someone', 'something', 'sometime', 'som ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(stop_words=stop_words)
X_train = vectorizer.fit_transform(raw_train["分词文章"])
X_test = vectorizer.transform(raw_test["分词文章"])

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5,weights="distance")
knn.fit(X_train, raw_train["分类"])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='distance')

# %%
Y_test = knn.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(9, 7))
## 设置正常显示中文
sns.set(font='SimHei')
## 绘制热力图
ax = sns.heatmap(confusion_matrix(raw_test["分类"].values,Y_test),linewidths=.5,cmap="Greens",
                 annot=True, fmt='d',xticklabels=knn.classes_, yticklabels=knn.classes_)
ax.set_ylabel('真实')
ax.set_xlabel('预测')
ax.xaxis.set_label_position('top') 
ax.xaxis.tick_top()
ax.set_title('混淆矩阵热力图')
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus']=False
